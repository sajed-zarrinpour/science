# %% [markdown]
# lets import the data first and see how it goes.

# %%
import pandas as pd
  
# makes the passed rows header
data = pd.read_csv("laplace.csv", header =[0])

# %%
data
# Out:
#             x    y        u
# 0     0.00000  0.0  0.00000
# 1     0.03125  0.0  0.03125
# 2     0.06250  0.0  0.06250
# 3     0.09375  0.0  0.09375
# 4     0.12500  0.0  0.12500
# ...       ...  ...      ...
# 1084  0.87500  1.0  0.87500
# 1085  0.90625  1.0  0.90625
# 1086  0.93750  1.0  0.93750
# 1087  0.96875  1.0  0.96875
# 1088  1.00000  1.0  1.00000
#
# [1089 rows x 3 columns]

# %%
import numpy as np
converted = np.array(data)

# %%
#import sys
#!{sys.executable} -m pip install sklearn

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(converted[:,0:2], converted[:,2], test_size=0.33, random_state=42)

# %% [markdown]
# OK, The first section would be a surrogate model, Next Section would be a PINN method

# %%
import numpy as np
import matplotlib.pyplot as plt
import os
# Keras :
from keras import backend as K
import tensorflow as tf
import keras 
from keras.layers import Input, Dense, add, Activation, Reshape , Conv1D, Flatten ,GlobalAveragePooling1D , Lambda, Dropout, concatenate
from keras.models import Model, model_from_json, model_from_yaml
from keras import optimizers 
from keras.callbacks import CSVLogger
from keras.losses import mse
from keras.utils.generic_utils import get_custom_objects

# %%
# network input parameters 
n = 2            # number of the input layer neurons 
# convolutional layers parameters
alpha = 14       # number of channels in convolutional layers
ks = 1           # Kernel Size
# optimizer (NAdam) parameters
lr = 0.005       # learning rate
beta_1=0.9       # beta 1
beta_2=0.999     # beta 2
# model fitting parameters
epochs = 5     # epochs
batch_size = 50 # batch size

# %%
inputTensor = Input(shape=(n,1))
print(inputTensor)

stack = []

# Part 1: Convolutional layers:
# SubPart 1.1 : Expanding the input to alpha channels and performing convolutions with kernel size of ks
stack.append(Conv1D(alpha, ks, strides=1, input_shape=(1,n,1),padding='same', activation='relu')(inputTensor))
stack.append(Conv1D(alpha, ks, strides=1, padding='same', activation='relu')(add([stack[len(stack)-1],inputTensor])))
stack.append(Conv1D(alpha, ks, strides=1, padding='same', activation='relu')(add([stack[len(stack)-1],inputTensor])))
# SubPart 1.2 : Flattening the results into 1 chanel
stack.append(Conv1D(1, ks, strides=1, padding='same', activation='linear')(add([stack[len(stack)-1],inputTensor])))

# Part 2: Sum-Pooling:
# there is no sumpooling direct layer, so we have to use an global average layer first :
stack.append(GlobalAveragePooling1D(data_format='channels_last')(add([stack[len(stack)-1],inputTensor])))
# and then multiply the result in the total number of elements throughh a lambda layer next:
stack.append(Lambda(lambda x: x * data.shape[1])(stack[len(stack)-1]))

# Part 3: Convolutions equivalent to Dense layers
# SubPart 3.1 : Expanding the input to alpha channels and performing convolution with kernel size 'ks'
stack.append(Conv1D(alpha, ks, strides=1, padding='same', activation='relu')(add([stack[len(stack)-1],inputTensor])))
stack.append(Conv1D(alpha, ks, strides=1, padding='same', activation='relu')(add([stack[len(stack)-1],inputTensor])))
stack.append(Conv1D(alpha, ks, strides=1, padding='same', activation='relu')(add([stack[len(stack)-1],inputTensor])))

# SubPart 3.2 : Flattening alpha channels to 1 channel, so the whole part can be viewd as a dense layer
#shall the kernel size remain 1? or we can use a more dynamic kernel size here
stack.append(Conv1D(1, ks, strides=1, padding='same', activation='linear')(add([stack[len(stack)-1],inputTensor])))

# SubPart 3.3 : Flattening the result so it can be fed into the output layer
stack.append(Flatten()(stack[len(stack)-1])) 

# SubPart 3.4 : The output layer which is a n -> 1 dense layer and will give us one single output 
finalOutput = Dense(1)(stack[len(stack)-1])
print(finalOutput)

# Defining the Actual Model
model = Model(inputTensor,finalOutput)
# Out:
# KerasTensor(type_spec=TensorSpec(shape=(None, 2, 1), dtype=tf.float32, name='input_1'), name='input_1', description="created by layer 'input_1'")
# KerasTensor(type_spec=TensorSpec(shape=(None, 1), dtype=tf.float32, name=None), name='dense/BiasAdd:0', description="created by layer 'dense'")

# %%
class EarlyStoppingAtMinLoss(tf.keras.callbacks.Callback):
  """Stop training when the loss is at its min, i.e. the loss stops decreasing.

  Arguments:
      patience: Number of epochs to wait after min has been hit. After this
      number of no improvement, training stops.
  """

  def __init__(self, patience=20):
    super(EarlyStoppingAtMinLoss, self).__init__()

    self.patience = patience

    # best_weights to store the weights at which the minimum loss occurs.
    self.best_weights = None

  def on_train_begin(self, logs=None):
    # The number of epoch it has waited when loss is no longer minimum.
    self.wait = 0
    # The epoch the training stops at.
    self.stopped_epoch = 0
    # Initialize the best as infinity.
    self.best = np.Inf

  def on_epoch_end(self, epoch, logs=None):
    current = logs.get('loss')
    if np.less(current, self.best):
      self.best = current
      self.wait = 0
      # Record the best weights if current results is better (less).
      self.best_weights = self.model.get_weights()
    else:
      self.wait += 1
      if self.wait >= self.patience:
        self.stopped_epoch = epoch
        self.model.stop_training = True
        print('Restoring model weights from the end of the best epoch.')
        self.model.set_weights(self.best_weights)

  def on_train_end(self, logs=None):
    if self.stopped_epoch > 0:
      print('Epoch %05d: early stopping' % (self.stopped_epoch + 1))

# %%
# Setting the optimizer parameters
opt = optimizers.Nadam(lr=lr, beta_1=beta_1, beta_2=beta_2)
# compiling the model
model.compile(loss='mean_squared_error', optimizer=opt, metrics=['mae'])

# %%
# fitting the data with model (learning process)
history = model.fit(X_train, y_train,validation_split=0.15, epochs=50, batch_size=batch_size, callbacks=[EarlyStoppingAtMinLoss(15)])
# Out:
# Epoch 1/50
# 13/13 [==============================] - 6s 143ms/step - loss: 0.8940 - mae: 0.7606 - val_loss: 0.1882 - val_mae: 0.3574
# Epoch 2/50
# 13/13 [==============================] - 1s 52ms/step - loss: 0.1777 - mae: 0.3480 - val_loss: 0.1366 - val_mae: 0.3026
# Epoch 3/50
# 13/13 [==============================] - 1s 54ms/step - loss: 0.1296 - mae: 0.2964 - val_loss: 0.0876 - val_mae: 0.2409
# Epoch 4/50
# 13/13 [==============================] - 1s 65ms/step - loss: 0.0871 - mae: 0.2436 - val_loss: 0.0555 - val_mae: 0.1930
# Epoch 5/50
# 13/13 [==============================] - 1s 59ms/step - loss: 0.0532 - mae: 0.1907 - val_loss: 0.0375 - val_mae: 0.1601
# Epoch 6/50
# 13/13 [==============================] - 1s 48ms/step - loss: 0.0348 - mae: 0.1572 - val_loss: 0.0285 - val_mae: 0.1414
# Epoch 7/50
# 13/13 [==============================] - 1s 69ms/step - loss: 0.0273 - mae: 0.1394 - val_loss: 0.0244 - val_mae: 0.1320
# Epoch 8/50
# 13/13 [==============================] - 1s 72ms/step - loss: 0.0242 - mae: 0.1304 - val_loss: 0.0224 - val_mae: 0.1260
# Epoch 9/50
# 13/13 [==============================] - 1s 57ms/step - loss: 0.0223 - mae: 0.1252 - val_loss: 0.0216 - val_mae: 0.1232
# Epoch 10/50
# 13/13 [==============================] - 1s 81ms/step - loss: 0.0206 - mae: 0.1183 - val_loss: 0.0210 - val_mae: 0.1207
# Epoch 11/50
# 13/13 [==============================] - 1s 75ms/step - loss: 0.0206 - mae: 0.1178 - val_loss: 0.0207 - val_mae: 0.1200
# Epoch 12/50
# 13/13 [==============================] - 1s 57ms/step - loss: 0.0192 - mae: 0.1147 - val_loss: 0.0204 - val_mae: 0.1188
# Epoch 13/50
# 13/13 [==============================] - 1s 65ms/step - loss: 0.0205 - mae: 0.1175 - val_loss: 0.0200 - val_mae: 0.1175
# Epoch 14/50
# 13/13 [==============================] - 1s 58ms/step - loss: 0.0213 - mae: 0.1201 - val_loss: 0.0196 - val_mae: 0.1165
# Epoch 15/50
# 13/13 [==============================] - 1s 50ms/step - loss: 0.0207 - mae: 0.1185 - val_loss: 0.0192 - val_mae: 0.1152
# Epoch 16/50
# 13/13 [==============================] - 1s 56ms/step - loss: 0.0211 - mae: 0.1218 - val_loss: 0.0188 - val_mae: 0.1138
# Epoch 17/50
# 13/13 [==============================] - 1s 44ms/step - loss: 0.0196 - mae: 0.1159 - val_loss: 0.0183 - val_mae: 0.1121
# Epoch 18/50
# 13/13 [==============================] - 1s 51ms/step - loss: 0.0188 - mae: 0.1136 - val_loss: 0.0179 - val_mae: 0.1111
# Epoch 19/50
# 13/13 [==============================] - 1s 71ms/step - loss: 0.0164 - mae: 0.1040 - val_loss: 0.0176 - val_mae: 0.1111
# Epoch 20/50
# 13/13 [==============================] - 1s 76ms/step - loss: 0.0171 - mae: 0.1079 - val_loss: 0.0171 - val_mae: 0.1093
# Epoch 21/50
# 13/13 [==============================] - 1s 65ms/step - loss: 0.0178 - mae: 0.1109 - val_loss: 0.0167 - val_mae: 0.1085
# Epoch 22/50
# 13/13 [==============================] - 1s 58ms/step - loss: 0.0162 - mae: 0.1048 - val_loss: 0.0161 - val_mae: 0.1057
# Epoch 23/50
# 13/13 [==============================] - 1s 66ms/step - loss: 0.0161 - mae: 0.1052 - val_loss: 0.0161 - val_mae: 0.1071
# Epoch 24/50
# 13/13 [==============================] - 1s 63ms/step - loss: 0.0156 - mae: 0.1027 - val_loss: 0.0152 - val_mae: 0.1035
# Epoch 25/50
# 13/13 [==============================] - 1s 62ms/step - loss: 0.0156 - mae: 0.1025 - val_loss: 0.0148 - val_mae: 0.1024
# Epoch 26/50
# 13/13 [==============================] - 1s 80ms/step - loss: 0.0146 - mae: 0.1006 - val_loss: 0.0143 - val_mae: 0.1001
# Epoch 27/50
# 13/13 [==============================] - 1s 61ms/step - loss: 0.0149 - mae: 0.1012 - val_loss: 0.0140 - val_mae: 0.0999
# Epoch 28/50
# 13/13 [==============================] - 1s 66ms/step - loss: 0.0135 - mae: 0.0972 - val_loss: 0.0135 - val_mae: 0.0980
# Epoch 29/50
# 13/13 [==============================] - 1s 82ms/step - loss: 0.0142 - mae: 0.0991 - val_loss: 0.0132 - val_mae: 0.0973
# Epoch 30/50
# 13/13 [==============================] - 1s 65ms/step - loss: 0.0123 - mae: 0.0922 - val_loss: 0.0124 - val_mae: 0.0928
# Epoch 31/50
# 13/13 [==============================] - 1s 66ms/step - loss: 0.0128 - mae: 0.0948 - val_loss: 0.0121 - val_mae: 0.0932
# Epoch 32/50
# 13/13 [==============================] - 1s 56ms/step - loss: 0.0118 - mae: 0.0909 - val_loss: 0.0115 - val_mae: 0.0912
# Epoch 33/50
# 13/13 [==============================] - 1s 62ms/step - loss: 0.0118 - mae: 0.0910 - val_loss: 0.0109 - val_mae: 0.0882
# Epoch 34/50
# 13/13 [==============================] - 1s 77ms/step - loss: 0.0108 - mae: 0.0860 - val_loss: 0.0108 - val_mae: 0.0885
# Epoch 35/50
# 13/13 [==============================] - 1s 76ms/step - loss: 0.0107 - mae: 0.0872 - val_loss: 0.0100 - val_mae: 0.0846
# Epoch 36/50
# 13/13 [==============================] - 1s 57ms/step - loss: 0.0095 - mae: 0.0821 - val_loss: 0.0096 - val_mae: 0.0831
# Epoch 37/50
# 13/13 [==============================] - 1s 58ms/step - loss: 0.0095 - mae: 0.0817 - val_loss: 0.0091 - val_mae: 0.0810
# Epoch 38/50
# 13/13 [==============================] - 1s 43ms/step - loss: 0.0098 - mae: 0.0836 - val_loss: 0.0089 - val_mae: 0.0808
# Epoch 39/50
# 13/13 [==============================] - 1s 55ms/step - loss: 0.0088 - mae: 0.0795 - val_loss: 0.0084 - val_mae: 0.0785
# Epoch 40/50
# 13/13 [==============================] - 1s 50ms/step - loss: 0.0083 - mae: 0.0769 - val_loss: 0.0084 - val_mae: 0.0786
# Epoch 41/50
# 13/13 [==============================] - 1s 51ms/step - loss: 0.0078 - mae: 0.0745 - val_loss: 0.0075 - val_mae: 0.0740
# Epoch 42/50
# 13/13 [==============================] - 1s 53ms/step - loss: 0.0073 - mae: 0.0718 - val_loss: 0.0071 - val_mae: 0.0725
# Epoch 43/50
# 13/13 [==============================] - 1s 58ms/step - loss: 0.0071 - mae: 0.0714 - val_loss: 0.0066 - val_mae: 0.0696
# Epoch 44/50
# 13/13 [==============================] - 1s 60ms/step - loss: 0.0064 - mae: 0.0680 - val_loss: 0.0062 - val_mae: 0.0675
# Epoch 45/50
# 13/13 [==============================] - 1s 67ms/step - loss: 0.0065 - mae: 0.0689 - val_loss: 0.0059 - val_mae: 0.0660
# Epoch 46/50
# 13/13 [==============================] - 1s 43ms/step - loss: 0.0059 - mae: 0.0658 - val_loss: 0.0059 - val_mae: 0.0663
# Epoch 47/50
# 13/13 [==============================] - 1s 51ms/step - loss: 0.0052 - mae: 0.0612 - val_loss: 0.0052 - val_mae: 0.0612
# Epoch 48/50
# 13/13 [==============================] - 1s 49ms/step - loss: 0.0051 - mae: 0.0599 - val_loss: 0.0050 - val_mae: 0.0612
# Epoch 49/50
# 13/13 [==============================] - 1s 54ms/step - loss: 0.0049 - mae: 0.0599 - val_loss: 0.0048 - val_mae: 0.0596
# Epoch 50/50
# 13/13 [==============================] - 1s 58ms/step - loss: 0.0044 - mae: 0.0563 - val_loss: 0.0042 - val_mae: 0.0558

# %%
# evaluating the results
loss, MAE= model.evaluate(X_test, y_test)
# printing the final results on test data set
print('Loss Funcion Minima On test dataset : %.8f' % (loss))
print('Mean Absolute Error On test dataset : %.8f' % (MAE))
# Out:
# 12/12 [==============================] - 0s 15ms/step - loss: 0.0044 - mae: 0.0560
# Loss Funcion Minima On test dataset : 0.00436768
# Mean Absolute Error On test dataset : 0.05602737

# %%
predicted_u = model.predict(X_test,batch_size=150)
print('mean of predicted A_eff : %.8f' % (np.mean(predicted_u)))
print('norm of the mean of the commited error : %.8f' % (np.linalg.norm(np.mean(predicted_u) - np.mean(y_test))))
# Out:
# mean of predicted A_eff : 0.50159729
# norm of the mean of the commited error : 0.00029520

# %%
err =[]
for i in range(len(predicted_u)):
    err.append(predicted_u[i]-y_test[i])
err = np.array(err)
print('mean of L2 commited error: %.8f'%(np.linalg.norm(err)))
# Out:
# mean of L2 commited error: 1.25393987

# %%
L2_Errors = []
for i in range(predicted_u.shape[0]):
    L2_Errors.append((y_test[i] - predicted_u[i])**2)

import matplotlib.pyplot as plt
plt.plot(L2_Errors)
plt.title('L2 error of the predicted eigenvalues')
plt.ylabel('commited error on instance')
plt.xlabel('index of instance')
plt.show()

# %%
T1 = 0
T2 = 5e-6
T3 = 5e-5
T4 = 5e-4
T5 = 5e-3
T6 = 5e-2
T7 = 5e-1
S1=S2=S3=S4=S5=S6=0.0
for item in L2_Errors:
    if (item[0]>=T1 and item[0]< T2):
        S1 = S1 + 1
    elif (item[0]>=T2 and item[0]< T3):
        S2 = S2 + 1
    elif (item[0]>=T3 and item[0]< T4):
        S3 = S3 + 1
    elif (item[0]>=T4 and item[0]< T5):
        S4 = S4 + 1
    elif (item[0]>=T5 and item[0]< T6):
        S5 = S5 + 1
    elif (item[0]>=T6 and item[0]< T7):
        S6 = S6 + 1
print('Percentage of the commited error between 0,5e-6 is: %.8f' % ((S1/len(L2_Errors)) * 100))
print('Percentage of the commited error between 5e-6,5e-5 is: %.8f' % ((S2/len(L2_Errors)) * 100))
print('Percentage of the commited error between 5e-5,5e-4 is: %.8f' % ((S3/len(L2_Errors)) * 100))
print('Percentage of the commited error between 5e-4,5e-3 is: %.8f' % ((S4/len(L2_Errors)) * 100))
print('Percentage of the commited error between 5e-3,5e-2 is: %.8f' % ((S5/len(L2_Errors)) * 100))
print('Percentage of the commited error between 5e-2,5e-1 is: %.8f' % ((S6/len(L2_Errors)) * 100))
# Out:
# Percentage of the commited error between 0,5e-6 is: 2.22222222
# Percentage of the commited error between 5e-6,5e-5 is: 4.16666667
# Percentage of the commited error between 5e-5,5e-4 is: 15.83333333
# Percentage of the commited error between 5e-4,5e-3 is: 42.50000000
# Percentage of the commited error between 5e-3,5e-2 is: 35.27777778
# Percentage of the commited error between 5e-2,5e-1 is: 0.00000000

# %%
fig, ax = plt.subplots(figsize=(12, 6), subplot_kw=dict(aspect="equal"))


data_to_plot = [(S1/len(L2_Errors)),
          (S2/len(L2_Errors)),
          (S3/len(L2_Errors)),
          (S4/len(L2_Errors)),
          (S5/len(L2_Errors)),
          (S6/len(L2_Errors))]
ingredients = ["0, 5e-6", 
               "5e-6, 5e-5",
               "5e-5, 5e-4",
               "5e-4, 5e-3",
               "5e-3, 5e-2",
               "5e-2, 5e-1",]


def func(pct, allvals):
    return "{:.1f}".format(pct)


wedges, texts, autotexts = ax.pie(data_to_plot, autopct=lambda pct: func(pct, data_to_plot),
                                  textprops=dict(color="w"))

ax.legend(wedges, ingredients,
          title="Error bounds",
          loc="center left",
          bbox_to_anchor=(1, 0, 0.5, 1))

plt.setp(autotexts, size=8, weight="bold")

ax.set_title("error percentages")

plt.show()

# %%
print(history.history.keys())
# summarize history for accuracy
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('metric over epochs for predicted eigenvalues')
plt.ylabel('mean absolute error')
plt.xlabel('epoch')
plt.legend(['MAE E train', 'MAE E test'], loc='upper left')
#plt.show()
plt.savefig('plot1.pdf', bbox_inches='tight')
# Out:
# dict_keys(['loss', 'mae', 'val_loss', 'val_mae'])

# %%
plt.plot(history.history['mae'])
plt.plot(history.history['val_mae'])
plt.title('metric over epochs for predicted eigenvectors')
plt.ylabel('mean absolute error')
plt.xlabel('epoch')
plt.legend(['MAE U train', 'MAE U test'], loc='upper left')
plt.show()
plt.savefig('pl.pdf', bbox_inches='tight')

# %%
input1 = keras.layers.Input(shape=(1, ))
input2 = keras.layers.Input(shape=(1,))
merged = keras.layers.Concatenate(axis=1)([input1, input2])
dense1 = keras.layers.Dense(2, input_dim=2, activation=keras.activations.sigmoid, use_bias=True)(merged)
output = keras.layers.Dense(1, activation=keras.activations.relu, use_bias=True)(dense1)
model2 = keras.models.Model(inputs=[input1, input2], outputs=output)

# %%
model2.compile(optimizer=opt,
             loss='mse',
             metrics=['mae']
             )

# %%
# fitting the data with model (learning process)
history2 = model2.fit([X_train[:,0], X_train[:,1]], y_train,validation_split=0.15, epochs=50, batch_size=batch_size, callbacks=[EarlyStoppingAtMinLoss(15)])
# Out:
# Epoch 1/50
# 13/13 [==============================] - 2s 46ms/step - loss: 0.3365 - mae: 0.5017 - val_loss: 0.3433 - val_mae: 0.5020
# Epoch 2/50
# 13/13 [==============================] - 0s 21ms/step - loss: 0.3445 - mae: 0.5081 - val_loss: 0.3433 - val_mae: 0.5020
# Epoch 3/50
# 13/13 [==============================] - 0s 22ms/step - loss: 0.3248 - mae: 0.4907 - val_loss: 0.3433 - val_mae: 0.5020
# Epoch 4/50
# 13/13 [==============================] - 0s 29ms/step - loss: 0.3202 - mae: 0.4879 - val_loss: 0.3433 - val_mae: 0.5020
# Epoch 5/50
# 13/13 [==============================] - 0s 30ms/step - loss: 0.3363 - mae: 0.5035 - val_loss: 0.3433 - val_mae: 0.5020
# Epoch 6/50
# 13/13 [==============================] - 0s 27ms/step - loss: 0.3277 - mae: 0.4920 - val_loss: 0.3433 - val_mae: 0.5020
# Epoch 7/50
# 13/13 [==============================] - 0s 32ms/step - loss: 0.3222 - mae: 0.4889 - val_loss: 0.3433 - val_mae: 0.5020
# Epoch 8/50
# 13/13 [==============================] - 0s 31ms/step - loss: 0.3283 - mae: 0.4958 - val_loss: 0.3433 - val_mae: 0.5020
# Epoch 9/50
# 13/13 [==============================] - 0s 35ms/step - loss: 0.3179 - mae: 0.4860 - val_loss: 0.3433 - val_mae: 0.5020
# Epoch 10/50
# 13/13 [==============================] - 0s 33ms/step - loss: 0.3300 - mae: 0.4951 - val_loss: 0.3433 - val_mae: 0.5020
# Epoch 11/50
# 13/13 [==============================] - 0s 33ms/step - loss: 0.3407 - mae: 0.5063 - val_loss: 0.3433 - val_mae: 0.5020
# Epoch 12/50
# 13/13 [==============================] - 0s 25ms/step - loss: 0.3180 - mae: 0.4854 - val_loss: 0.3433 - val_mae: 0.5020
# Epoch 13/50
# 13/13 [==============================] - 0s 20ms/step - loss: 0.3279 - mae: 0.4910 - val_loss: 0.3433 - val_mae: 0.5020
# Epoch 14/50
# 13/13 [==============================] - 0s 22ms/step - loss: 0.3280 - mae: 0.4941 - val_loss: 0.3433 - val_mae: 0.5020
# Epoch 15/50
# 13/13 [==============================] - 0s 26ms/step - loss: 0.3352 - mae: 0.4962 - val_loss: 0.3433 - val_mae: 0.5020
# Epoch 16/50
# 13/13 [==============================] - 0s 27ms/step - loss: 0.3386 - mae: 0.5068 - val_loss: 0.3433 - val_mae: 0.5020
# Restoring model weights from the end of the best epoch.
# Epoch 00016: early stopping

# %%
# evaluating the results
loss,MAE = model2.evaluate([X_test[:,0],X_test[:,0]], y_test)
# printing the final results on test data set
#print('LOSS : %.8f' % (loss))
#print('MAE : %.8f' % (MSE))
#print('MAE : %.8f' % (MAE))
# Out:
# 12/12 [==============================] - 0s 11ms/step - loss: 0.3464 - mae: 0.5013

# %%
predicted_u = model2.predict([X_test[:,0],X_test[:,0]],batch_size=150)
print('mean of prediction : %.8f' % (np.mean(predicted_u)))
print('norm of the mean of the commited error : %.8f' % (np.linalg.norm(np.mean(predicted_u) - np.mean(y_test))))
# Out:
# mean of prediction : 0.00000000
# norm of the mean of the commited error : 0.50130208

# %%
err =[]
for i in range(len(predicted_u)):
    err.append(predicted_u[i]-y_test[i])
err = np.array(err)
print('mean of L2 commited error: %.8f'%(np.linalg.norm(err)))
# Out:
# mean of L2 commited error: 11.16639900

# %%
L2_Errors = []
for i in range(predicted_u.shape[0]):
    L2_Errors.append((y_test[i] - predicted_u[i])**2)

import matplotlib.pyplot as plt
plt.plot(L2_Errors)
plt.title('L2 error of the predicted eigenvalues')
plt.ylabel('commited error on instance')
plt.xlabel('index of instance')
plt.show()

# %%
T1 = 0
T2 = 5e-6
T3 = 5e-5
T4 = 5e-4
T5 = 5e-3
T6 = 5e-2
T7 = 5e-1
S1=S2=S3=S4=S5=S6=0.0
for item in L2_Errors:
    if (item[0]>=T1 and item[0]< T2):
        S1 = S1 + 1
    elif (item[0]>=T2 and item[0]< T3):
        S2 = S2 + 1
    elif (item[0]>=T3 and item[0]< T4):
        S3 = S3 + 1
    elif (item[0]>=T4 and item[0]< T5):
        S4 = S4 + 1
    elif (item[0]>=T5 and item[0]< T6):
        S5 = S5 + 1
    elif (item[0]>=T6 and item[0]< T7):
        S6 = S6 + 1
print('Percentage of the commited error between 0,5e-6 is: %.8f' % ((S1/len(L2_Errors)) * 100))
print('Percentage of the commited error between 5e-6,5e-5 is: %.8f' % ((S2/len(L2_Errors)) * 100))
print('Percentage of the commited error between 5e-5,5e-4 is: %.8f' % ((S3/len(L2_Errors)) * 100))
print('Percentage of the commited error between 5e-4,5e-3 is: %.8f' % ((S4/len(L2_Errors)) * 100))
print('Percentage of the commited error between 5e-3,5e-2 is: %.8f' % ((S5/len(L2_Errors)) * 100))
print('Percentage of the commited error between 5e-2,5e-1 is: %.8f' % ((S6/len(L2_Errors)) * 100))
# Out:
# Percentage of the commited error between 0,5e-6 is: 2.77777778
# Percentage of the commited error between 5e-6,5e-5 is: 0.00000000
# Percentage of the commited error between 5e-5,5e-4 is: 0.00000000
# Percentage of the commited error between 5e-4,5e-3 is: 7.77777778
# Percentage of the commited error between 5e-3,5e-2 is: 15.27777778
# Percentage of the commited error between 5e-2,5e-1 is: 41.38888889

# %%
fig, ax = plt.subplots(figsize=(12, 6), subplot_kw=dict(aspect="equal"))


data_to_plot = [(S1/len(L2_Errors)),
          (S2/len(L2_Errors)),
          (S3/len(L2_Errors)),
          (S4/len(L2_Errors)),
          (S5/len(L2_Errors)),
          (S6/len(L2_Errors))]
ingredients = ["0, 5e-6", 
               "5e-6, 5e-5",
               "5e-5, 5e-4",
               "5e-4, 5e-3",
               "5e-3, 5e-2",
               "5e-2, 5e-1",]


def func(pct, allvals):
    return "{:.1f}".format(pct)


wedges, texts, autotexts = ax.pie(data_to_plot, autopct=lambda pct: func(pct, data_to_plot),
                                  textprops=dict(color="w"))

ax.legend(wedges, ingredients,
          title="Error bounds",
          loc="center left",
          bbox_to_anchor=(1, 0, 0.5, 1))

plt.setp(autotexts, size=8, weight="bold")

ax.set_title("error percentages")

plt.show()
# Out:
# <ipython-input-33-11cfd84edcf2>:22: MatplotlibDeprecationWarning: normalize=None does not normalize if the sum is less than 1 but this behavior is deprecated since 3.3 until two minor releases later. After the deprecation period the default value will be normalize=True. To prevent normalization pass normalize=False
#   wedges, texts, autotexts = ax.pie(data_to_plot, autopct=lambda pct: func(pct, data_to_plot),

# %%
print(history.history.keys())
# summarize history for accuracy
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('metric over epochs for predicted eigenvalues')
plt.ylabel('mean absolute error')
plt.xlabel('epoch')
plt.legend(['MAE E train', 'MAE E test'], loc='upper left')
#plt.show()
plt.savefig('plot1.pdf', bbox_inches='tight')
# Out:
# dict_keys(['loss', 'mae', 'val_loss', 'val_mae'])

# %%
plt.plot(history.history['mae'])
plt.plot(history.history['val_mae'])
plt.title('metric over epochs for predicted eigenvectors')
plt.ylabel('mean absolute error')
plt.xlabel('epoch')
plt.legend(['MAE U train', 'MAE U test'], loc='upper left')
plt.show()
plt.savefig('pl.pdf', bbox_inches='tight')

# %%
model2.summary()
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_2 (InputLayer)            [(None, 1)]          0
# __________________________________________________________________________________________________
# input_3 (InputLayer)            [(None, 1)]          0
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, 2)            0           input_2[0][0]
#                                                                  input_3[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 2)            6           concatenate[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 1)            3           dense_1[0][0]
# ==================================================================================================
# Total params: 9
# Trainable params: 9
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
x = keras.layers.Input(shape=(1, ))
y = keras.layers.Input(shape=(1,))
merged = keras.layers.Concatenate(axis=1)([x, y])
dense1 = keras.layers.Dense(2, input_dim=2, activation=keras.activations.sigmoid, use_bias=True)(merged)
u = keras.layers.Dense(1, activation=keras.activations.relu, use_bias=True)(dense1)
model3 = keras.models.Model(inputs=[x, y], outputs=u)

# %%
model3.summary()
# Out:
# Model: "model_2"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_4 (InputLayer)            [(None, 1)]          0
# __________________________________________________________________________________________________
# input_5 (InputLayer)            [(None, 1)]          0
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 2)            0           input_4[0][0]
#                                                                  input_5[0][0]
# __________________________________________________________________________________________________
# dense_3 (Dense)                 (None, 2)            6           concatenate_1[0][0]
# __________________________________________________________________________________________________
# dense_4 (Dense)                 (None, 1)            3           dense_3[0][0]
# ==================================================================================================
# Total params: 9
# Trainable params: 9
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
inp = tf.Variable(np.random.normal(size=(1, 1)), dtype=tf.float32)
inp2 = tf.Variable(np.random.normal(size=(1, 1)), dtype=tf.float32)

with tf.GradientTape() as tape:
    preds = model3([inp,inp2])
grads = tape.gradient(preds, [inp,inp2])

# %%
grads
# Out:
# [<tf.Tensor: shape=(1, 1), dtype=float32, numpy=array([[0.]], dtype=float32)>,
#  <tf.Tensor: shape=(1, 1), dtype=float32, numpy=array([[0.]], dtype=float32)>]

# %%
x = tf.Variable(np.random.normal(size=(1, 1)), dtype=tf.float32)
y = tf.Variable(np.random.normal(size=(1, 1)), dtype=tf.float32)
with tf.GradientTape(watch_accessed_variables=False) as gx:
    gx.watch(x)
    with tf.GradientTape(watch_accessed_variables=False) as ggx:
        ggx.watch(x)
        u = model3([x, y])
    du_dx = ggx.gradient(u, x)  
d2u_dx2 = gx.gradient(du_dx, x)  

with tf.GradientTape(watch_accessed_variables=False) as gy:
    gy.watch(y)
    with tf.GradientTape(watch_accessed_variables=False) as ggy:
        ggy.watch(y)
        u = model3([x, y])  
    du_dy = ggy.gradient(u, y)  
d2u_dy2 = gy.gradient(du_dy, y)


print(du_dx)
print(d2u_dx2)

print(du_dy)
print(d2u_dy2)
# Out:
# tf.Tensor([[0.]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.]], shape=(1, 1), dtype=float32)

# %%
def loss_wrapper(y_true, y_pred):
    print(y_pred)
    print(y_true)
    # the final formula for this loss is :
    # - grad(u) = 0

    # grad(u)
    #g = K.gradients(model3.get_output_at(0)[0], [model3.get_input_at(0)[0], model3.get_input_at(0)[1]])
    #gg = K.gradients(g, [model3.get_input_at(0)[0], model3.get_input_at(0)[1]])
    
    x = tf.Variable(np.random.normal(size=(1, 1)), dtype=tf.float32)
    y = tf.Variable(np.random.normal(size=(1, 1)), dtype=tf.float32)
    with tf.GradientTape(watch_accessed_variables=False) as gx:
        gx.watch(x)
        with tf.GradientTape(watch_accessed_variables=False) as ggx:
            ggx.watch(x)
            u = y_pred#model3([x, y])
        du_dx = ggx.gradient(u, x)  
    d2u_dx2 = gx.gradient(du_dx, x)  

    with tf.GradientTape(watch_accessed_variables=False) as gy:
        gy.watch(y)
        with tf.GradientTape(watch_accessed_variables=False) as ggy:
            ggy.watch(y)
            u = y_pred#model3([x, y])  
        du_dy = ggy.gradient(u, y)  
    d2u_dy2 = gy.gradient(du_dy, y)

    #u_pred = y_pred[0]
    #u_true = y_true[0]

    # tf.tensordot(a, u, 1) 0 for    ooouter product,  1 for inner product
    #losss = -tf.tensordot(tf.reshape(gg[0], [-1]),tf.reshape(gg[1], [-1]),1) + tf.tensordot(a, u, 1) + 2*u**3 - E*u

    #losss = - tf.tensordot(
    #                        tf.reshape(d2u_dx2, [-1]), 
    #                        tf.reshape(d2u_dy2, [-1]),
    #                        1
    #                      )
    losss = - d2u_dx2 * d2u_dy2
    return K.sum(losss)

# %%
losses ={u.name.split('/')[0]: loss_wrapper}
lossWeights={u.name.split('/')[0]: 1}
custom_metrics ={u.name.split('/')[0]: ['mse','mae']}

# %%
model3.compile(optimizer=opt,
             loss=losses,
             loss_weights= lossWeights,
             metrics=custom_metrics
             )

# %%
# fitting the data with model (learning process)
history3 = model3.fit([X_train[:,0], X_train[:,1]], y_train,validation_split=0.15, epochs=50, batch_size=batch_size, callbacks=[EarlyStoppingAtMinLoss(15)])
# Out:
# Epoch 1/50
# Tensor("model_2/dense_4/Relu:0", shape=(None, 1), dtype=float32)
# Tensor("ExpandDims_2:0", shape=(None, 1), dtype=float32)
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-68-674c6bfc4a93> in <module>
#       1 # fitting the data with model (learning process)
# ----> 2 history3 = model3.fit([X_train[:,0], X_train[:,1]], y_train,validation_split=0.15, epochs=50, batch_size=batch_size, callbacks=[EarlyStoppingAtMinLoss(15)])
#
# ~/anaconda3/envs/tf/lib/python3.8/site-packages/tensorflow/python/keras/engine/training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1098                 _r=1):
#    1099               callbacks.on_train_batch_begin(step)
# -> 1100               tmp_logs = self.train_function(iterator)
#    1101               if data_handler.should_sync:
#    1102                 context.async_wait()
#
# ~/anaconda3/envs/tf/lib/python3.8/site-packages/tensorflow/python/eager/def_function.py in __call__(self, *args, **kwds)
#     826     tracing_count = self.experimental_get_tracing_count()
#     827     with trace.Trace(self._name) as tm:
# --> 828       result = self._call(*args, **kwds)
#     829       compiler = "xla" if self._experimental_compile else "nonXla"
#     830       new_tracing_count = self.experimental_get_tracing_count()
#
# ~/anaconda3/envs/tf/lib/python3.8/site-packages/tensorflow/python/eager/def_function.py in _call(self, *args, **kwds)
#     869       # This is the first call of __call__, so we have to initialize.
#     870       initializers = []
# --> 871       self._initialize(args, kwds, add_initializers_to=initializers)
#     872     finally:
#     873       # At this point we know that the initialization is complete (or less
#
# ~/anaconda3/envs/tf/lib/python3.8/site-packages/tensorflow/python/eager/def_function.py in _initialize(self, args, kwds, add_initializers_to)
#     723     self._graph_deleter = FunctionDeleter(self._lifted_initializer_graph)
#     724     self._concrete_stateful_fn = (
# --> 725         self._stateful_fn._get_concrete_function_internal_garbage_collected(  # pylint: disable=protected-access
#     726             *args, **kwds))
#     727
#
# ~/anaconda3/envs/tf/lib/python3.8/site-packages/tensorflow/python/eager/function.py in _get_concrete_function_internal_garbage_collected(self, *args, **kwargs)
#    2967       args, kwargs = None, None
#    2968     with self._lock:
# -> 2969       graph_function, _ = self._maybe_define_function(args, kwargs)
#    2970     return graph_function
#    2971
#
# ~/anaconda3/envs/tf/lib/python3.8/site-packages/tensorflow/python/eager/function.py in _maybe_define_function(self, args, kwargs)
#    3359
#    3360           self._function_cache.missed.add(call_context_key)
# -> 3361           graph_function = self._create_graph_function(args, kwargs)
#    3362           self._function_cache.primary[cache_key] = graph_function
#    3363
#
# ~/anaconda3/envs/tf/lib/python3.8/site-packages/tensorflow/python/eager/function.py in _create_graph_function(self, args, kwargs, override_flat_arg_shapes)
#    3194     arg_names = base_arg_names + missing_arg_names
#    3195     graph_function = ConcreteFunction(
# -> 3196         func_graph_module.func_graph_from_py_func(
#    3197             self._name,
#    3198             self._python_function,
#
# ~/anaconda3/envs/tf/lib/python3.8/site-packages/tensorflow/python/framework/func_graph.py in func_graph_from_py_func(name, python_func, args, kwargs, signature, func_graph, autograph, autograph_options, add_control_dependencies, arg_names, op_return_value, collections, capture_by_value, override_flat_arg_shapes)
#     988         _, original_func = tf_decorator.unwrap(python_func)
#     989
# --> 990       func_outputs = python_func(*func_args, **func_kwargs)
#     991
#     992       # invariant: `func_outputs` contains only Tensors, CompositeTensors,
#
# ~/anaconda3/envs/tf/lib/python3.8/site-packages/tensorflow/python/eager/def_function.py in wrapped_fn(*args, **kwds)
#     632             xla_context.Exit()
#     633         else:
# --> 634           out = weak_wrapped_fn().__wrapped__(*args, **kwds)
#     635         return out
#     636
#
# ~/anaconda3/envs/tf/lib/python3.8/site-packages/tensorflow/python/framework/func_graph.py in wrapper(*args, **kwargs)
#     975           except Exception as e:  # pylint:disable=broad-except
#     976             if hasattr(e, "ag_error_metadata"):
# --> 977               raise e.ag_error_metadata.to_exception(e)
#     978             else:
#     979               raise
#
# TypeError: in user code:
#
#     /home/samim/anaconda3/envs/tf/lib/python3.8/site-packages/tensorflow/python/keras/engine/training.py:805 train_function  *
#         return step_function(self, iterator)
#     <ipython-input-65-dcf8eba7c245>:19 loss_wrapper  *
#         d2u_dx2 = gx.gradient(du_dx, x)
#     /home/samim/anaconda3/envs/tf/lib/python3.8/site-packages/tensorflow/python/eager/backprop.py:1047 gradient  **
#         if not backprop_util.IsTrainable(t):
#     /home/samim/anaconda3/envs/tf/lib/python3.8/site-packages/tensorflow/python/eager/backprop_util.py:30 IsTrainable
#         dtype = dtypes.as_dtype(dtype)
#     /home/samim/anaconda3/envs/tf/lib/python3.8/site-packages/tensorflow/python/framework/dtypes.py:649 as_dtype
#         raise TypeError("Cannot convert value %r to a TensorFlow DType." %
#
#     TypeError: Cannot convert value None to a TensorFlow DType.

# %%
model3.get_input_at(0)
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-69-9bdd6313a2dc> in <module>
# ----> 1 model3.get_input_at(0)
#
# ~/anaconda3/envs/tf/lib/python3.8/site-packages/tensorflow/python/keras/engine/base_layer.py in get_input_at(self, node_index)
#    2095       RuntimeError: If called in Eager mode.
#    2096     """
# -> 2097     return self._get_node_attribute_at_index(node_index, 'input_tensors',
#    2098                                              'input')
#    2099
#
# ~/anaconda3/envs/tf/lib/python3.8/site-packages/tensorflow/python/keras/engine/base_layer.py in _get_node_attribute_at_index(self, node_index, attr, attr_name)
#    2667     """
#    2668     if not self._inbound_nodes:
# -> 2669       raise RuntimeError('The layer has never been called '
#    2670                          'and thus has no defined ' + attr_name + '.')
#    2671     if not len(self._inbound_nodes) > node_index:
#
# RuntimeError: The layer has never been called and thus has no defined input.
